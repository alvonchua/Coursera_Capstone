# %% [markdown]
# ### 1. Create Dataframe for List of Postal Code in Canada

# %%
pip install lxml html5lib beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
#read the tables in the wiki page
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
df = pd.read_html(url)

# %%
#Retrieve the first neighborhood table from wiki
df = df[0]
df.head()
# Out:
#   Postal Code           Borough              Neighbourhood
# 0         M1A      Not assigned               Not assigned
# 1         M2A      Not assigned               Not assigned
# 2         M3A        North York                  Parkwoods
# 3         M4A        North York           Victoria Village
# 4         M5A  Downtown Toronto  Regent Park, Harbourfront

# %%
#Remove rows with Borough = 'Not assigned'
df = df.loc[df['Borough']!='Not assigned']

#Renumber defaulted index 
df.reset_index(inplace = True)

df.head(12)
# Out:
#     index Postal Code           Borough  \
# 0       2         M3A        North York
# 1       3         M4A        North York
# 2       4         M5A  Downtown Toronto
# 3       5         M6A        North York
# 4       6         M7A  Downtown Toronto
# 5       8         M9A         Etobicoke
# 6       9         M1B       Scarborough
# 7      11         M3B        North York
# 8      12         M4B         East York
# 9      13         M5B  Downtown Toronto
# 10     14         M6B        North York
# 11     17         M9B         Etobicoke
#
#                                         Neighbourhood
# 0                                           Parkwoods
# 1                                    Victoria Village
# 2                           Regent Park, Harbourfront
# 3                    Lawrence Manor, Lawrence Heights
# 4         Queen's Park, Ontario Provincial Government
# 5             Islington Avenue, Humber Valley Village
# 6                                      Malvern, Rouge
# ...

# %%
#Remove redundant 'index' column
df = df.drop(columns = 'index')
df.head()
# Out:
#   Postal Code           Borough                                Neighbourhood
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
#Check if there are any 'Not assigned' Neighbourhood
df[df['Neighbourhood'] == 'Not assigned'].shape
# Out:
# (0, 3)

# %%
#Find the shape of the dataframe
df.shape
# Out:
# (103, 3)
